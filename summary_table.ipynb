# %%
import pandas as pd
df = pd.read_csv(
    'UKFlora.csv', 
    sep=',', 
    low_memory=False, 
    usecols=['AccSpeciesName', 'OrigUnitStr', 'DataName', 'OrigValueStr'] # dont bother with columns we wont use

)

# %%
# attach units to data names in case we need them later
df['DataName'] = df['DataName'] + '(' + df['OrigUnitStr'] + ')'

# %%
type_map = {}

# make a dict mapping data name values to their types
# try float then string. don't bother with int as it won't work for columns with NaN values
# without messing about with deep pandas features: 
# https://pandas.pydata.org/pandas-docs/stable/user_guide/integer_na.html#integer-na

for name, group in df.groupby('DataName'):
    for my_type in (float, str):
        try:
            coerced = group['OrigValueStr'].astype(my_type)
            type_map[name] = my_type
            break
        except:
            pass
type_map
# Out:
# {'Actual EvapoTranspiration(mm)': float,
#  'Altitude (maximum recorded)(m)': str,
#  'Altitude (minimum recorded)(m)': str,
#  'Altitude (typical minimum)(m)': float,
#  'Altitude(m)': float,
#  'Average annual relative humidity(%)': float,
#  'Average number of ground frost days per year (sum) (FRS)(d/y)': float,
#  'Chromosome cDNA content(pg)': float,
#  'Chromosome cDNA content(pg/2C-Nucleus)': float,
#  'Cloud cover(%)': float,
#  'Dispersal unit (dispersule / diaspore) length(mm)': str,
#  'Ecosystem rooting depth(m)': float,
#  'End of flowering(month)': float,
#  'Fern  and moss spore width (diameter)(microm)': float,
#  'Fine root diameter(microm)': str,
#  'First historical record: 1. date(year)': float,
#  'Flower pollen ovule ratio(1/Ovulo)': float,
#  'Flowering periode: peak month(month)': float,
#  'Fraction of absorbed photosynthetic active radiation (FAPAR) of the site(no unit)': float,
#  'GPP of the site(gC/m2)': float,
#  'Inbreeding(%)': str,
#  'Intensity of mycorrhizal infection(%)': str,
#  'Leaf Relative water content (water content / water content at saturation)(%)': float,
#  'Leaf Water content (molar) per leaf dry mass (WCd)(mmol/g)': float,
#  'Leaf Water content saturating (molar) (WCs)(mmol/g)': float,
#  'Leaf Water content total (molar) (WCt)(mmol/g)': float,
#  'Leaf area index of the site (LAI)(m2/m2)': float,
#  'Leaf area: in case of compound leaves undefined if leaf or leaflet; undefined if petiole and rhachis in- or excluded(cm2)': str,
#  'Leaf carbon content per dry mass(%)': float,
#  'Leaf carbon/nitrogen (C/N) ratio(g/g)': float,
#  'Leaf carotenoid content per dry mass(mg g-1)': float,
#  'Leaf chlorophyll a content per dry mass(mg g-1)': float,
#  'Leaf chlorophyll b content per dry mass(mg g-1)': float,
#  'Leaf chlorophyll content (a+b) per dry mass(mg g-1)': float,
#  'Leaf dry matter content per leaf water-saturated mass (LDMC)(mg/g)': float,
#  'Leaf lamina thickness(mm)': str,
#  'Leaf lifespan (longevity, retention time, LL)(month)': str,
#  'Leaf nitrogen content per dry mass (Nmass)(%)': float,
#  'Leaf nitrogen content per dry mass (Nmass)(mg/g)': str,
#  'Leaf petiole length(mm)': float,
#  'Leaf phosphorus content per dry mass (Pmass)(%)': float,
#  'Leaf phosphorus content per dry mass (Pmass)(mg/g)': str,
#  'Leaf respiration per dry mass(nmol g-1s-1)': float,
#  'Leaf thickness(mm)': float,
#  'Leaf tissue density(mg/cm3)': float,
#  'Leaf transpiration (molar) per dry mass(mmol/g/s)': float,
#  'Leaf transpiration rate per dry mass (daytime)(gH2O/(g dry mass · h))': float,
#  'Leaf water content per leaf dry mass(gH2O/g dry mass)': float,
#  'Leaf water content per leaf water-saturated mass (LWC, 1-LDMC)(gH2O / 100 g fresh mass)': float,
#  'Leaf water content saturating(gH2O/g dry mass)': float,
#  'Leaf water content total(gH2O/g dry mass)': float,
#  'Leaf water saturation deficit(%)': float,
#  'Maximum Green Vegetation Fraction(%)': float,
#  'Maximum temperature at which 50% seeds germinate(C)': float,
#  'Maximum temperature of germination(C)': float,
#  'Mean annual sum of potential evapotranspiration (PET)(mm)': float,
#  'Mean annual temperature (MAT)(C)': float,
#  'Mean clear-sky surface radiation budget from ERBE global: Global shortwave radiation budget data derived from 5 Years of ERBE measurements(w/m2)': float,
#  'Mean cloud forcing surface radiation budget from ERBE global: Global shortwave radiation budget data derived from 5 Years of ERBE measurements(w/m2)': float,
#  'Mean cloud surface radiation budget from ERBE global: Global shortwave radiation budget data derived from 5 Years of ERBE measurements(w/m2)': float,
#  'Mean number of wet days per year(d/y)': float,
#  'Mean sum of annual precipitation (PPT / MAP / TAP)(mm)': float,
#  'Minimum temperature at which 50% seeds germinate(C)': float,
#  'Minimum temperature germination(C)': float,
#  'NDVI of the site(no unit)': float,
#  'NPP of the site (2)(gC/m2)': float,
#  'Net primary productivity of the site (NPP)(gC/m2)': float,
#  'Number of European countries in which native(countries)': float,
#  'Onset of flowering (first flowering date, beginning of flowering period)(month)': str,
#  'Photoperiodism: threshold value (h)(h)': float,
#  'Photosynthesis per leaf dry mass (Amass)(nmol g-1s-1)': float,
#  'Plant height (unspecified if vegetative or reproductive)(cm)': str,
#  'Plant relative growth rate (RGR)(1/day)': str,
#  'Pollen: 2. diameter (um)(microm)': float,
#  'Precipitation Seasonality (Coefficient of Variation)(mm)': float,
#  'Precipitation of Coldest Quarter(mm)': float,
#  'Precipitation of Driest Month(mm)': float,
#  'Precipitation of Driest Quarter(mm)': float,
#  'Precipitation of Warmest Quarter(mm)': float,
#  'Precipitation of Wettest Month(mm)': float,
#  'Precipitation of Wettest Quarter(mm)': float,
#  'Root hair length(mm)': str,
#  'Root persistence (livespan, longevity)(years)': str,
#  'Root rooting depth (cm)': str,
#  'Root rooting depth (text)': str,
#  'SLA: undefined if petiole in- or excluded(SLA cm2/g)': float,
#  'Seed / ovule ratio(1/reproduction_unit)': str,
#  'Seed dry mass(mg)': str,
#  'Seed length (largest dimension length)(mm)': str,
#  'Seed number per plant(1/plant)': str,
#  'Seedbank density(m-2 ?)': str,
#  'Seedbank longevity(month)': str,
#  'Seedbank longevity(text)': str,
#  'Seedbank longevity(year)': str,
#  'Seeds per flower(1/flower)': str,
#  'Soil C content per ground area(kg/m2)': float,
#  'Soil N content per ground area(g/m2)': float,
#  'Soil bulk density(g/cm3)': float,
#  'Soil field capacity(mm)': float,
#  'Soil ph(no unit)': float,
#  'Soil plant available water capacity of rooting zone (derived from remote sensing) 1(mm)': float,
#  'Soil plant available water capacity of rooting zone (derived from remote sensing) 2(mm)': float,
#  'Soil profile available water capacity(mm)': float,
#  'Soil thermal capacity(J/m3/K)': float,
#  'Soil water content (SWC)(%)': float,
#  'Soil wilting point(mm)': float,
#  'Solar radiation (kJ m-2 day-1)(kJ m-2 day-1)': float,
#  'Stem longevity(yrs)': str,
#  'Stomata density on lower surface(mm-2)': str,
#  'Stomata density on upper surface(mm-2)': str,
#  'Stomata density(1/mm2)': float,
#  'Temperature sum of growing degree days (GDD)(C)': float,
#  'Temperature: Annual Range(C)': float,
#  'Temperature: Max Temperature of Warmest Month(C)': float,
#  'Temperature: Mean Diurnal Range (Mean of monthly (max temp - min temp))(C)': float,
#  'Temperature: Mean Temperature of Coldest Quarter(C)': float,
#  'Temperature: Mean Temperature of Driest Quarter(C)': float,
#  'Temperature: Mean Temperature of Warmest Quarter(C)': float,
#  'Temperature: Mean Temperature of Wettest Quarter(C)': float,
#  'Temperature: Min Temperature of Coldest Month(C)': float,
#  'Temperature: Seasonality (standard deviation *100)(C)': float,
#  'Terrestrial chlorophyll index of the site(no unit)': float,
#  'Water vapor pressure (kPa)(kPa)': float,
#  'Wind speed (m s-1)(m s-1)': float}

# %%
# takes a Series of values and aggregates them to a single value based on types in the dict
# for floats, take the median
# for strings, take the most common value
# replace this with your real logic :-)

def aggregate(values):
    species, data_name = values.name
    target_type = type_map[data_name]
    #print(data_name, target_type)

    coerced_data = values.astype(target_type)
    
    if target_type  == float:
        return coerced_data.median()
    else:
        return coerced_data.value_counts().index[0]
    
# make a summary table with the aggregated values
summary = df.groupby(['AccSpeciesName', 'DataName'])['OrigValueStr'].apply(aggregate).unstack()

# %%
# convert the columns in the summary table to the correct types
# using the dict from before

for c in summary.columns:
    summary[c] = summary[c].astype(type_map[c])

# %%
summary.dtypes
# Out:
# DataName
# Actual EvapoTranspiration(mm)                                                                                                float64
# Altitude (maximum recorded)(m)                                                                                                object
# Altitude (minimum recorded)(m)                                                                                                object
# Altitude (typical minimum)(m)                                                                                                float64
# Altitude(m)                                                                                                                  float64
# Average annual relative humidity(%)                                                                                          float64
# Average number of ground frost days per year (sum) (FRS)(d/y)                                                                float64
# Chromosome cDNA content(pg)                                                                                                  float64
# Chromosome cDNA content(pg/2C-Nucleus)                                                                                       float64
# Cloud cover(%)                                                                                                               float64
# Dispersal unit (dispersule / diaspore) length(mm)                                                                             object
# Ecosystem rooting depth(m)                                                                                                   float64
# End of flowering(month)                                                                                                      float64
# Fern  and moss spore width (diameter)(microm)                                                                                float64
# Fine root diameter(microm)                                                                                                    object
# First historical record: 1. date(year)                                                                                       float64
# Flower pollen ovule ratio(1/Ovulo)                                                                                           float64
# Flowering periode: peak month(month)                                                                                         float64
# Fraction of absorbed photosynthetic active radiation (FAPAR) of the site(no unit)                                            float64
# GPP of the site(gC/m2)                                                                                                       float64
# Inbreeding(%)                                                                                                                 object
# Intensity of mycorrhizal infection(%)                                                                                         object
# Leaf Relative water content (water content / water content at saturation)(%)                                                 float64
# Leaf Water content (molar) per leaf dry mass (WCd)(mmol/g)                                                                   float64
# Leaf Water content saturating (molar) (WCs)(mmol/g)                                                                          float64
# Leaf Water content total (molar) (WCt)(mmol/g)                                                                               float64
# Leaf area index of the site (LAI)(m2/m2)                                                                                     float64
# Leaf area: in case of compound leaves undefined if leaf or leaflet; undefined if petiole and rhachis in- or excluded(cm2)     object
# Leaf carbon content per dry mass(%)                                                                                          float64
# Leaf carbon/nitrogen (C/N) ratio(g/g)                                                                                        float64
#                                                                                                                               ...
# Seeds per flower(1/flower)                                                                                                    object
# Soil C content per ground area(kg/m2)                                                                                        float64
# Soil N content per ground area(g/m2)                                                                                         float64
# Soil bulk density(g/cm3)                                                                                                     float64
# Soil field capacity(mm)                                                                                                      float64
# Soil ph(no unit)                                                                                                             float64
# Soil plant available water capacity of rooting zone (derived from remote sensing) 1(mm)                                      float64
# Soil plant available water capacity of rooting zone (derived from remote sensing) 2(mm)                                      float64
# Soil profile available water capacity(mm)                                                                                    float64
# Soil thermal capacity(J/m3/K)                                                                                                float64
# Soil water content (SWC)(%)                                                                                                  float64
# Soil wilting point(mm)                                                                                                       float64
# Solar radiation (kJ m-2 day-1)(kJ m-2 day-1)                                                                                 float64
# Stem longevity(yrs)                                                                                                           object
# Stomata density on lower surface(mm-2)                                                                                        object
# Stomata density on upper surface(mm-2)                                                                                        object
# Stomata density(1/mm2)                                                                                                       float64
# Temperature sum of growing degree days (GDD)(C)                                                                              float64
# Temperature: Annual Range(C)                                                                                                 float64
# Temperature: Max Temperature of Warmest Month(C)                                                                             float64
# Temperature: Mean Diurnal Range (Mean of monthly (max temp - min temp))(C)                                                   float64
# Temperature: Mean Temperature of Coldest Quarter(C)                                                                          float64
# Temperature: Mean Temperature of Driest Quarter(C)                                                                           float64
# Temperature: Mean Temperature of Warmest Quarter(C)                                                                          float64
# Temperature: Mean Temperature of Wettest Quarter(C)                                                                          float64
# Temperature: Min Temperature of Coldest Month(C)                                                                             float64
# Temperature: Seasonality (standard deviation *100)(C)                                                                        float64
# Terrestrial chlorophyll index of the site(no unit)                                                                           float64
# Water vapor pressure (kPa)(kPa)                                                                                              float64
# Wind speed (m s-1)(m s-1)                                                                                                    float64
# Length: 124, dtype: object

# %%
# to figure out why certain columns aren't being sucessfully converted to numerical types
# find all the unique individual values in each data name that can't be converted to float

for name, group in df.groupby('DataName'):
    non_floats = set()
    for value in group['OrigValueStr']:
        try:
            float(value)
        except:
            non_floats.add(value)
    if len(non_floats) > 0:
        print(name)
        print(non_floats)
        print()
# Out:
# Altitude (maximum recorded)(m)
# {'1,200'}
#
# Altitude (minimum recorded)(m)
# {'-'}
#
# Dispersal unit (dispersule / diaspore) length(mm)
# {'-'}
#
# Fine root diameter(microm)
# {'150-200', '<100', '100-150', '200-300', '300-500'}
#
# Inbreeding(%)
# {'90-95'}
#
# Intensity of mycorrhizal infection(%)
# {'rarely mycorrhizal', 'occasionally mycorrhizal', 'on soil only', 'not known in the wild', 'never mycorrhizal', 'rare', 'normally mycorrhizal'}
#
# Leaf area: in case of compound leaves undefined if leaf or leaflet; undefined if petiole and rhachis in- or excluded(cm2)
# {'>1000', '10-100', '1-10', '0.1-1', '100-1000', '<0.1'}
#
# Leaf lamina thickness(mm)
# {'>2.0', '0.5-1.0', '0.2-0.5', '<0.2', '1.0-2.0'}
#
# Leaf lifespan (longevity, retention time, LL)(month)
# {'12-24', '3-6', '6-12', '7-12', '2-6', '0-2', '>24'}
#
# Leaf nitrogen content per dry mass (Nmass)(mg/g)
# {'<5', '20-30', '5-10', '10-20', '>30'}
#
# Leaf phosphorus content per dry mass (Pmass)(mg/g)
# {'1-2', '<1', '2-3', '>3'}
#
# Onset of flowering (first flowering date, beginning of flowering period)(month)
# {'early spring'}
#
# Plant height (unspecified if vegetative or reproductive)(cm)
# {'simple'}
#
# Plant relative growth rate (RGR)(1/day)
# {'0.5-0.9'}
#
# Root hair length(mm)
# {'0.5-1.0', '1.0-5.0', '>5.0', '0.1-0.5'}
#
# Root persistence (livespan, longevity)(years)
# {'>1', '<1'}
#
# Root rooting depth (cm)
# {'0-10', '10-50', '>100', '50-100'}
#
# Root rooting depth (text)
# {'deep', 'shallow'}
#
# Seed / ovule ratio(1/reproduction_unit)
# {'0,171', '0.2 - 0.56', '143 - 2108'}
#
# Seed dry mass(mg)
# {'0,18', '0,32'}
#
# Seed length (largest dimension length)(mm)
# {'-', '0.9-1.1', '0.7-0.8', '1.0-1.1'}
#
# Seed number per plant(1/plant)
# {'>10000', '1000-10000', '10-100', '1-10', '100-1000'}
#
# Seedbank density(m-2 ?)
# {'absolute', 'partial', 'value? (seeds/m2)', '75,000', 'no seedbank recorded', '>200 000', 'no persistent seedbank recorded'}
#
# Seedbank longevity(month)
# {'3-12 months', '3-12', '<3 months'}
#
# Seedbank longevity(text)
# {'none recorded'}
#
# Seedbank longevity(year)
# {'5-20 yrs', '>20 yrs', '>20', '1-5 yrs', '5-20 years'}
#
# Seeds per flower(1/flower)
# {'1-10', '>1000', '10-100', '100-1000'}
#
# Stem longevity(yrs)
# {'2-10', '100-500', '<1', '10-100', '> 500', '1-2', '>500'}
#
# Stomata density on lower surface(mm-2)
# {'-', '124-160', '69-86', '+-2 (stem)', '220-310', '150-190'}
#
# Stomata density on upper surface(mm-2)
# {'130-260', '140-180'}

# %%
for labels, group in df.head(10000).groupby(['AccSpeciesName','DataName']):
    species, data = labels
    target_type = type_map[data]
    coerced_data = group['OrigValueStr'].astype(target_type)
# Out:
# ACAENA NOVAE-ZELANDIAE Altitude (minimum recorded)(m) ['0', '0']
# ACAENA NOVAE-ZELANDIAE End of flowering(month) [7]
# ACAENA NOVAE-ZELANDIAE First historical record: 1. date(year) [1901]
# ACAENA NOVAE-ZELANDIAE Onset of flowering (first flowering date, beginning of flowering period)(month) ['6', '6']
# ACAENA NOVAE-ZELANDIAE Plant height (unspecified if vegetative or reproductive)(cm) ['15', '2', '2']
# ACAENA NOVAE-ZELANDIAE Root rooting depth (cm) ['0-10']
# ACAENA NOVAE-ZELANDIAE Seed dry mass(mg) ['0.92']
# ACAENA NOVAE-ZELANDIAE Seed length (largest dimension length)(mm) ['2.0']
# ACAENA NOVAE-ZELANDIAE Seed number per plant(1/plant) ['1000-10000']
# ACAENA NOVAE-ZELANDIAE Seeds per flower(1/flower) ['1']
# ALISMA PLANTAGO-AQUATICA Altitude (maximum recorded)(m) ['381', '403']
# ALISMA PLANTAGO-AQUATICA Altitude (minimum recorded)(m) ['0', '0', '0']
# ALISMA PLANTAGO-AQUATICA Chromosome cDNA content(pg) [20.6]
# ALISMA PLANTAGO-AQUATICA Dispersal unit (dispersule / diaspore) length(mm) ['2.4', '2.4']
# ALISMA PLANTAGO-AQUATICA End of flowering(month) [8]
# ALISMA PLANTAGO-AQUATICA First historical record: 1. date(year) [1597]
# ALISMA PLANTAGO-AQUATICA Leaf area: in case of compound leaves undefined if leaf or leaflet; undefined if petiole and rhachis in- or excluded(cm2) ['100-1000']
# ALISMA PLANTAGO-AQUATICA Number of European countries in which native(countries) [29]
# ALISMA PLANTAGO-AQUATICA Onset of flowering (first flowering date, beginning of flowering period)(month) ['6']
# ALISMA PLANTAGO-AQUATICA Plant height (unspecified if vegetative or reproductive)(cm) ['100', '20', '20']
# ALISMA PLANTAGO-AQUATICA Seed dry mass(mg) ['0.27']
# ALISMA PLANTAGO-AQUATICA Seed number per plant(1/plant) ['>10000']
# ALISMA PLANTAGO-AQUATICA Seedbank density(m-2 ?) ['42021', '6015.75']
# ALISMA PLANTAGO-AQUATICA Stomata density on lower surface(mm-2) ['36', '36']
# ALISMA PLANTAGO-AQUATICA Stomata density on upper surface(mm-2) ['50']
# Acaena anserinifolia Plant height (unspecified if vegetative or reproductive)(cm) ['15']
# Acer campestre Altitude (maximum recorded)(m) ['380']
# Acer campestre Altitude (minimum recorded)(m) ['0', '0', '0']
# Acer campestre Dispersal unit (dispersule / diaspore) length(mm) ['30.0']
# Acer campestre End of flowering(month) [6, 6]
# Acer campestre First historical record: 1. date(year) [1570]
# Acer campestre Leaf area: in case of compound leaves undefined if leaf or leaflet; undefined if petiole and rhachis in- or excluded(cm2) ['10-100']
# Acer campestre Leaf petiole length(mm) [20.0, 80.0]
# Acer campestre Number of European countries in which native(countries) [24]
# Acer campestre Onset of flowering (first flowering date, beginning of flowering period)(month) ['5', '5', '5']
# Acer campestre Plant height (unspecified if vegetative or reproductive)(cm) ['2320', '1500', '900']
# Acer campestre Pollen: 2. diameter (um)(microm) [28.8]
# Acer campestre Root rooting depth (text) ['deep']
# Acer campestre Seed dry mass(mg) ['86.5', '56', '80.8']
# Acer campestre Seeds per flower(1/flower) ['1']
# Acer campestre Stem longevity(yrs) ['100-500']
# Acer campestre Stomata density on lower surface(mm-2) ['270']
# Acer campestre Stomata density on upper surface(mm-2) ['0.5']
# Acer platanoides Dispersal unit (dispersule / diaspore) length(mm) ['43.0']
# Acer platanoides End of flowering(month) [5, 5]
# Acer platanoides First historical record: 1. date(year) [1683]
# Acer platanoides Leaf area: in case of compound leaves undefined if leaf or leaflet; undefined if petiole and rhachis in- or excluded(cm2) ['10-100', '100-1000']
# Acer platanoides Leaf petiole length(mm) [50.0, 200.0]
# Acer platanoides Number of European countries in which native(countries) [20]
# Acer platanoides Onset of flowering (first flowering date, beginning of flowering period)(month) ['4', '4']
# Acer platanoides Plant height (unspecified if vegetative or reproductive)(cm) ['3000']
# Acer platanoides Seeds per flower(1/flower) ['1', '1', '1', '1']
# Acer pseudoplatanus Altitude (maximum recorded)(m) ['480']
# Acer pseudoplatanus Altitude (minimum recorded)(m) ['0', '0', '0']
# Acer pseudoplatanus Chromosome cDNA content(pg) [2.4, 4.0]
# Acer pseudoplatanus Dispersal unit (dispersule / diaspore) length(mm) ['43.0']
# Acer pseudoplatanus End of flowering(month) [6, 6, 6]
# Acer pseudoplatanus Leaf area: in case of compound leaves undefined if leaf or leaflet; undefined if petiole and rhachis in- or excluded(cm2) ['10-100', '100-1000']
# Acer pseudoplatanus Leaf nitrogen content per dry mass (Nmass)(mg/g) ['20-30']
# Acer pseudoplatanus Leaf petiole length(mm) [10.0, 200.0]
# Acer pseudoplatanus Leaf phosphorus content per dry mass (Pmass)(mg/g) ['2-3']
# Acer pseudoplatanus Number of European countries in which native(countries) [21]
# Acer pseudoplatanus Onset of flowering (first flowering date, beginning of flowering period)(month) ['4', '4']
# Acer pseudoplatanus Plant height (unspecified if vegetative or reproductive)(cm) ['3000', '1800']
# Acer pseudoplatanus Plant relative growth rate (RGR)(1/day) ['0.049']
# Acer pseudoplatanus Pollen: 2. diameter (um)(microm) [32.2, 48.0, 33.1]
# Acer pseudoplatanus Seed dry mass(mg) ['30.6']
# Acer pseudoplatanus Seed length (largest dimension length)(mm) ['6.4']
# Acer pseudoplatanus Seedbank density(m-2 ?) ['no persistent seedbank recorded']
# Acer pseudoplatanus Seeds per flower(1/flower) ['1']
# Acer pseudoplatanus Stem longevity(yrs) ['100-500']
# Acer pseudoplatanus Stomata density on lower surface(mm-2) ['400']
# Achillea millefolium Altitude (maximum recorded)(m) ['1213']
# Achillea millefolium Altitude (minimum recorded)(m) ['0', '0', '0']
# Achillea millefolium Chromosome cDNA content(pg) [14.4]
# Achillea millefolium Dispersal unit (dispersule / diaspore) length(mm) ['2.1', '2.1']
# Achillea millefolium First historical record: 1. date(year) [1538]
# Achillea millefolium Leaf area: in case of compound leaves undefined if leaf or leaflet; undefined if petiole and rhachis in- or excluded(cm2) ['1-10']
# Achillea millefolium Leaf lifespan (longevity, retention time, LL)(month) ['0-2']
# Achillea millefolium Maximum temperature at which 50% seeds germinate(C) [33]
# Achillea millefolium Number of European countries in which native(countries) [28]
# Achillea millefolium Onset of flowering (first flowering date, beginning of flowering period)(month) ['6', '6', '6']
# Achillea millefolium Plant height (unspecified if vegetative or reproductive)(cm) ['60', '45', '8', '8']
# Achillea millefolium Plant relative growth rate (RGR)(1/day) ['0.28']
# Achillea millefolium Pollen: 2. diameter (um)(microm) [25.5, 30.2]
# Achillea millefolium Root rooting depth (cm) ['10-50']
# Achillea millefolium Root rooting depth (text) ['deep']
# Achillea millefolium Seed / ovule ratio(1/reproduction_unit) ['0.48']
# Achillea millefolium Seed dry mass(mg) ['0.16']
# Achillea millefolium Seed number per plant(1/plant) ['1000-10000']
# Achillea millefolium Seedbank density(m-2 ?) ['1716', '4', '159.5263157894736842105263157894736', '4']
# Achillea millefolium Seedbank longevity(year) ['1-5 yrs']
# Achillea millefolium Seeds per flower(1/flower) ['10-100']
# Achillea millefolium Stomata density on lower surface(mm-2) ['16']
# Achillea millefolium Stomata density on upper surface(mm-2) ['103']
# Achillea ptarmica Altitude (maximum recorded)(m) ['731']
# Achillea ptarmica Altitude (minimum recorded)(m) ['0', '0', '0', '0', '0']
# Achillea ptarmica Dispersal unit (dispersule / diaspore) length(mm) ['1.8', '1.8']
# Achillea ptarmica End of flowering(month) [8]
# Achillea ptarmica First historical record: 1. date(year) [1597]
# Achillea ptarmica Leaf area: in case of compound leaves undefined if leaf or leaflet; undefined if petiole and rhachis in- or excluded(cm2) ['1-10']
# Achillea ptarmica Number of European countries in which native(countries) [21]
# Achillea ptarmica Onset of flowering (first flowering date, beginning of flowering period)(month) ['7', '7', '7']
# Achillea ptarmica Plant height (unspecified if vegetative or reproductive)(cm) ['60', '20']
# Achillea ptarmica Pollen: 2. diameter (um)(microm) [25.0]
# Achillea ptarmica Seed dry mass(mg) ['0.2']
# Achillea ptarmica Seedbank density(m-2 ?) ['113', '54', '84']
# Achillea ptarmica Stem longevity(yrs) ['<1']
# Achillea ptarmica Stomata density on lower surface(mm-2) ['125']
# Achillea ptarmica Stomata density on upper surface(mm-2) ['130']
# Aconitum napellus End of flowering(month) [6, 6]
# Aconitum napellus First historical record: 1. date(year) [1821]
# Aconitum napellus Number of European countries in which native(countries) [16]
# Aconitum napellus Onset of flowering (first flowering date, beginning of flowering period)(month) ['5', '5']
# Aconitum napellus Plant height (unspecified if vegetative or reproductive)(cm) ['100', '50']
# Aconitum napellus Seed dry mass(mg) ['3.62']
# Aconitum napellus Seed length (largest dimension length)(mm) ['4.5']
# Aconitum napellus Stem longevity(yrs) ['<1']
# Aconitum napellus Stomata density on lower surface(mm-2) ['71']
# Aconitum napellus Stomata density on upper surface(mm-2) ['0', '0']
# Acorus calamus End of flowering(month) [7, 7, 7]
# Acorus calamus First historical record: 1. date(year) [1666]
# Acorus calamus Leaf area: in case of compound leaves undefined if leaf or leaflet; undefined if petiole and rhachis in- or excluded(cm2) ['100-1000']
# Acorus calamus Leaf petiole length(mm) [0.0, 0.0, 0.0]
# Acorus calamus Onset of flowering (first flowering date, beginning of flowering period)(month) ['5']
# Acorus calamus Plant height (unspecified if vegetative or reproductive)(cm) ['100']
# Acorus calamus Pollen: 2. diameter (um)(microm) [21.0]
# Acorus calamus Seed dry mass(mg) ['9.1']
# Actaea spicata Altitude (maximum recorded)(m) ['450', '500']
# Actaea spicata Altitude (minimum recorded)(m) ['0', '25', '0', '0', '0']
# Actaea spicata Dispersal unit (dispersule / diaspore) length(mm) ['10.0']
# Actaea spicata End of flowering(month) [6, 6]
# Actaea spicata First historical record: 1. date(year) [1597]
# Actaea spicata Flower pollen ovule ratio(1/Ovulo) [3464.0]
# Actaea spicata Onset of flowering (first flowering date, beginning of flowering period)(month) ['5', '5']
# Actaea spicata Plant height (unspecified if vegetative or reproductive)(cm) ['65', '30']
# Actaea spicata Root rooting depth (cm) ['10-50']
# Actaea spicata Seed dry mass(mg) ['6.7']
# Actaea spicata Seed length (largest dimension length)(mm) ['4.0']
# Actaea spicata Seeds per flower(1/flower) ['12', '1-10']
# Actaea spicata Stem longevity(yrs) ['<1']
# Actaea spicata Stomata density on lower surface(mm-2) ['45']
# Adonis annua Dispersal unit (dispersule / diaspore) length(mm) ['6.0', '6.0']
# Adonis annua First historical record: 1. date(year) [1548]
# Adonis annua Leaf petiole length(mm) [0.0, 0.0]
# Adonis annua Number of European countries in which native(countries) [15]
# Adonis annua Onset of flowering (first flowering date, beginning of flowering period)(month) ['7', '7', '7', '7']
# Adonis annua Plant height (unspecified if vegetative or reproductive)(cm) ['40', '10']
# Adonis annua Seed dry mass(mg) ['18.4', '4.8']
# Adonis annua Stem longevity(yrs) ['<1']
# Adoxa moschatellina Altitude (maximum recorded)(m) ['1066']
# Adoxa moschatellina Altitude (minimum recorded)(m) ['0', '0', '0', '0']
# Adoxa moschatellina Chromosome cDNA content(pg) [28.6]
# Adoxa moschatellina First historical record: 1. date(year) [1570]
# Adoxa moschatellina Leaf area: in case of compound leaves undefined if leaf or leaflet; undefined if petiole and rhachis in- or excluded(cm2) ['1-10']
# Adoxa moschatellina Number of European countries in which native(countries) [21]
# Adoxa moschatellina Onset of flowering (first flowering date, beginning of flowering period)(month) ['4', '4']
# Adoxa moschatellina Plant height (unspecified if vegetative or reproductive)(cm) ['10', '5', '5', '5', '5']
# Adoxa moschatellina Pollen: 2. diameter (um)(microm) [26.0]
# Adoxa moschatellina Seed dry mass(mg) ['0.71']
# Adoxa moschatellina Seed number per plant(1/plant) ['10-100']
# Adoxa moschatellina Stem longevity(yrs) ['<1']
# Adoxa moschatellina Stomata density on lower surface(mm-2) ['45']
# Aegopodium podagraria Altitude (maximum recorded)(m) ['411']
# Aegopodium podagraria Altitude (minimum recorded)(m) ['0', '0', '0', '0']
# Aegopodium podagraria Dispersal unit (dispersule / diaspore) length(mm) ['4.0']
# Aegopodium podagraria End of flowering(month) [7, 7]
# Aegopodium podagraria Fine root diameter(microm) ['<100']
# Aegopodium podagraria First historical record: 1. date(year) [1578]
# Aegopodium podagraria Leaf area: in case of compound leaves undefined if leaf or leaflet; undefined if petiole and rhachis in- or excluded(cm2) ['10-100', '100-1000']
# Aegopodium podagraria Number of European countries in which native(countries) [19]
# Aegopodium podagraria Onset of flowering (first flowering date, beginning of flowering period)(month) ['5', '5']
# Aegopodium podagraria Plant height (unspecified if vegetative or reproductive)(cm) ['100', '40']
# Aegopodium podagraria Seed dry mass(mg) ['1.99']
# Aegopodium podagraria Stem longevity(yrs) ['<1']
# Aegopodium podagraria Stomata density on lower surface(mm-2) ['266']
# Aethusa cynapium Altitude (maximum recorded)(m) ['274']
# Aethusa cynapium Altitude (minimum recorded)(m) ['0', '0', '0']
# Aethusa cynapium Dispersal unit (dispersule / diaspore) length(mm) ['3.0']
# Aethusa cynapium End of flowering(month) [8]
# Aethusa cynapium Fine root diameter(microm) ['100-150']
# Aethusa cynapium First historical record: 1. date(year) [1597]
# Aethusa cynapium Number of European countries in which native(countries) [22]
# Aethusa cynapium Onset of flowering (first flowering date, beginning of flowering period)(month) ['7', '7']
# Aethusa cynapium Plant height (unspecified if vegetative or reproductive)(cm) ['120', '5']
# Aethusa cynapium Seed dry mass(mg) ['1.64']
# Aethusa cynapium Seedbank density(m-2 ?) ['1625', '351.7857142857142857142857142857142']
# Aethusa cynapium Seeds per flower(1/flower) ['2', '1-10']
# Aethusa cynapium Stem longevity(yrs) ['<1']
# Agapanthus praecox Leaf petiole length(mm) [0.0, 0.0]
# Agapanthus praecox Plant height (unspecified if vegetative or reproductive)(cm) ['100']
# Agapanthus praecox Stem longevity(yrs) ['<1']
# Agrimonia eupatoria Altitude (maximum recorded)(m) ['490']
# Agrimonia eupatoria Altitude (minimum recorded)(m) ['0', '0', '0']
# Agrimonia eupatoria End of flowering(month) [8]
# Agrimonia eupatoria First historical record: 1. date(year) [1551]
# Agrimonia eupatoria Leaf area: in case of compound leaves undefined if leaf or leaflet; undefined if petiole and rhachis in- or excluded(cm2) ['10-100']
# Agrimonia eupatoria Number of European countries in which native(countries) [30, 30]
# Agrimonia eupatoria Onset of flowering (first flowering date, beginning of flowering period)(month) ['6']
# Agrimonia eupatoria Plant height (unspecified if vegetative or reproductive)(cm) ['60']
# Agrimonia eupatoria Pollen: 2. diameter (um)(microm) [48.0]
# Agrimonia eupatoria Seedbank density(m-2 ?) ['no persistent seedbank recorded']
# Agrimonia eupatoria Seeds per flower(1/flower) ['2', '1-10']
# Agrimonia eupatoria Stem longevity(yrs) ['<1']
# Agrimonia eupatoria Stomata density on lower surface(mm-2) ['200']
# Agrimonia eupatoria Stomata density on upper surface(mm-2) ['1']
# Agrimonia procera Altitude (maximum recorded)(m) ['335']
# Agrimonia procera Altitude (minimum recorded)(m) ['0', '0', '0']
# Agrimonia procera End of flowering(month) [8]
# Agrimonia procera First historical record: 1. date(year) [1853]
# Agrimonia procera Number of European countries in which native(countries) [23]
# Agrimonia procera Onset of flowering (first flowering date, beginning of flowering period)(month) ['6', '6']
# Agrimonia procera Stem longevity(yrs) ['<1']
# Agrostemma githago Altitude (maximum recorded)(m) ['600']
# Agrostemma githago Altitude (minimum recorded)(m) ['0', '0', '0', '0']
# Agrostemma githago Dispersal unit (dispersule / diaspore) length(mm) ['3.0', '3.0']
# Agrostemma githago End of flowering(month) [9]
# Agrostemma githago Fine root diameter(microm) ['200-300']
# Agrostemma githago First historical record: 1. date(year) [1538]
# Agrostemma githago Flowering periode: peak month(month) [6, 7, 7, 6]
# Agrostemma githago Leaf area: in case of compound leaves undefined if leaf or leaflet; undefined if petiole and rhachis in- or excluded(cm2) ['1-10']
# Agrostemma githago Number of European countries in which native(countries) [30, 30]
# Agrostemma githago Plant height (unspecified if vegetative or reproductive)(cm) ['150', '5', '100', '5', '5', '5']
# Agrostemma githago Root hair length(mm) ['1.0-5.0']
# Agrostemma githago Seed dry mass(mg) ['26', '8', '12', '15']
# Agrostemma githago Seed number per plant(1/plant) ['100-1000', '100-1000']
# Agrostemma githago Seedbank density(m-2 ?) ['no persistent seedbank recorded']
# Agrostemma githago Seedbank longevity(month) ['<3 months']
# Agrostemma githago Seeds per flower(1/flower) ['42', '10-100']
# Agrostemma githago Stem longevity(yrs) ['<1']
# Agrostemma githago Stomata density on lower surface(mm-2) ['40', '40']
# Agrostis canina Altitude (maximum recorded)(m) ['1036']
# Agrostis canina Chromosome cDNA content(pg) [7.0]
# Agrostis canina Dispersal unit (dispersule / diaspore) length(mm) ['1.7']
# Agrostis canina End of flowering(month) [7, 7, 7]
# Agrostis canina First historical record: 1. date(year) [1762]
# Agrostis canina Leaf area: in case of compound leaves undefined if leaf or leaflet; undefined if petiole and rhachis in- or excluded(cm2) ['1-10']
# Agrostis canina Leaf petiole length(mm) [0.0, 0.0, 0.0]
# Agrostis canina Maximum temperature at which 50% seeds germinate(C) [30]
# Agrostis canina Minimum temperature at which 50% seeds germinate(C) [9]
# Agrostis canina Number of European countries in which native(countries) [26]
# Agrostis canina Onset of flowering (first flowering date, beginning of flowering period)(month) ['6']
# Agrostis canina Plant height (unspecified if vegetative or reproductive)(cm) ['70', '10']
# Agrostis canina Plant relative growth rate (RGR)(1/day) ['0.201']
# Agrostis canina Root rooting depth (text) ['shallow']
# Agrostis canina Seed dry mass(mg) ['0.05']
# Agrostis canina Seed length (largest dimension length)(mm) ['1.3']
# Agrostis canina Seedbank density(m-2 ?) ['5980', '18', '840.5454545454545454545454545454545']
# Agrostis canina Stem longevity(yrs) ['<1']
# Agrostis capillaris Altitude (maximum recorded)(m) ['1213']
# Agrostis capillaris Altitude (minimum recorded)(m) ['0', '0', '0', '0', '0']
# Agrostis capillaris Chromosome cDNA content(pg) [7.1]
# Agrostis capillaris Dispersal unit (dispersule / diaspore) length(mm) ['1.9']
# Agrostis capillaris End of flowering(month) [8]
# Agrostis capillaris First historical record: 1. date(year) [1670]
# Agrostis capillaris Leaf area: in case of compound leaves undefined if leaf or leaflet; undefined if petiole and rhachis in- or excluded(cm2) ['1-10']
# Agrostis capillaris Leaf nitrogen content per dry mass (Nmass)(mg/g) ['10-20']
# Agrostis capillaris Leaf phosphorus content per dry mass (Pmass)(mg/g) ['1-2']
# Agrostis capillaris Maximum temperature at which 50% seeds germinate(C) [31]
# Agrostis capillaris Minimum temperature at which 50% seeds germinate(C) [7]
# Agrostis capillaris Number of European countries in which native(countries) [26]
# Agrostis capillaris Onset of flowering (first flowering date, beginning of flowering period)(month) ['6', '6']
# Agrostis capillaris Plant height (unspecified if vegetative or reproductive)(cm) ['70', '10']
# Agrostis capillaris Plant relative growth rate (RGR)(1/day) ['0.194']
# Agrostis capillaris Root rooting depth (cm) ['50-100']
# Agrostis capillaris Seed dry mass(mg) ['0.06']
# Agrostis capillaris Seed length (largest dimension length)(mm) ['1.0']
# Agrostis capillaris Seedbank density(m-2 ?) ['17750', '9', '930.5128205128205128205128205128205']
# Agrostis capillaris Seedbank longevity(year) ['5-20 yrs']
# Agrostis capillaris Stem longevity(yrs) ['<1']
# Agrostis castellana End of flowering(month) [8]
# Agrostis castellana Leaf petiole length(mm) [0.0, 0.0]
# Agrostis castellana Number of European countries in which native(countries) [10]
# Agrostis castellana Onset of flowering (first flowering date, beginning of flowering period)(month) ['6']
# Agrostis castellana Plant height (unspecified if vegetative or reproductive)(cm) ['60']
# Agrostis castellana Seedbank density(m-2 ?) ['125', '125', '125']
# Agrostis castellana Stem longevity(yrs) ['<1']
# Agrostis curtisii Altitude (maximum recorded)(m) ['609']
# Agrostis curtisii End of flowering(month) [7, 7]
# Agrostis curtisii First historical record: 1. date(year) [1778]
# Agrostis curtisii Leaf area: in case of compound leaves undefined if leaf or leaflet; undefined if petiole and rhachis in- or excluded(cm2) ['0.1-1']
# Agrostis curtisii Leaf petiole length(mm) [0.0, 0.0, 0.0]
# Agrostis curtisii Number of European countries in which native(countries) [4]
# Agrostis curtisii Onset of flowering (first flowering date, beginning of flowering period)(month) ['6', '6']
# Agrostis curtisii Plant height (unspecified if vegetative or reproductive)(cm) ['70', '60', '20']
# Agrostis curtisii Root rooting depth (cm) ['10-50']
# Agrostis curtisii Seed length (largest dimension length)(mm) ['1.5']
# Agrostis curtisii Stem longevity(yrs) ['<1']
# Agrostis gigantea End of flowering(month) [8]
# Agrostis gigantea Leaf area: in case of compound leaves undefined if leaf or leaflet; undefined if petiole and rhachis in- or excluded(cm2) ['1-10', '10-100']
# Agrostis gigantea Leaf petiole length(mm) [0.0, 0.0, 0.0]
# Agrostis gigantea Number of European countries in which native(countries) [22]
# Agrostis gigantea Onset of flowering (first flowering date, beginning of flowering period)(month) ['6', '6', '6']
# Agrostis gigantea Plant height (unspecified if vegetative or reproductive)(cm) ['70', '10']
# Agrostis gigantea Seed dry mass(mg) ['0.09']
# Agrostis gigantea Seedbank density(m-2 ?) ['4833', '100', '1444.333333333333333333333333333333']
# Agrostis gigantea Stem longevity(yrs) ['<1']
# Agrostis stolonifera Altitude (maximum recorded)(m) ['746']
# Agrostis stolonifera Altitude (minimum recorded)(m) ['0', '0', '0', '0']
# Agrostis stolonifera Chromosome cDNA content(pg) [7.0]
# Agrostis stolonifera Dispersal unit (dispersule / diaspore) length(mm) ['1.5']
# Agrostis stolonifera End of flowering(month) [8, 8]
# Agrostis stolonifera Leaf area: in case of compound leaves undefined if leaf or leaflet; undefined if petiole and rhachis in- or excluded(cm2) ['1-10']
# Agrostis stolonifera Maximum temperature at which 50% seeds germinate(C) [36]
# Agrostis stolonifera Minimum temperature at which 50% seeds germinate(C) [11]
# Agrostis stolonifera Number of European countries in which native(countries) [33]
# Agrostis stolonifera Onset of flowering (first flowering date, beginning of flowering period)(month) ['7', '7', '7']
# Agrostis stolonifera Plant height (unspecified if vegetative or reproductive)(cm) ['150', '5', '100', '15']
# Agrostis stolonifera Root rooting depth (text) ['shallow']
# Agrostis stolonifera Seed dry mass(mg) ['0.02']
# Agrostis stolonifera Seed length (largest dimension length)(mm) ['1.0']
# Agrostis stolonifera Seedbank density(m-2 ?) ['7300', '518.4565217391304347826086956521739']
# Agrostis stolonifera Stem longevity(yrs) ['<1']
# Agrostis stolonifera Stomata density on lower surface(mm-2) ['56']
# Agrostis stolonifera Stomata density on upper surface(mm-2) ['80']
# Agrostis vinealis Chromosome cDNA content(pg) [6.9]
# Agrostis vinealis Dispersal unit (dispersule / diaspore) length(mm) ['1.7', '2.5']
# Agrostis vinealis End of flowering(month) [8]
# Agrostis vinealis Leaf area: in case of compound leaves undefined if leaf or leaflet; undefined if petiole and rhachis in- or excluded(cm2) ['1-10']
# Agrostis vinealis Leaf petiole length(mm) [0.0, 0.0, 0.0]
# Agrostis vinealis Number of European countries in which native(countries) [15]
# Agrostis vinealis Onset of flowering (first flowering date, beginning of flowering period)(month) ['6', '6']
# Agrostis vinealis Plant height (unspecified if vegetative or reproductive)(cm) ['70', '10']
# Agrostis vinealis Seed dry mass(mg) ['0.06']
# Agrostis vinealis Seedbank density(m-2 ?) ['69', '65', '67']
# Agrostis vinealis Stem longevity(yrs) ['<1']
# Ailanthus altissima Dispersal unit (dispersule / diaspore) length(mm) ['35']
# Ailanthus altissima Leaf area: in case of compound leaves undefined if leaf or leaflet; undefined if petiole and rhachis in- or excluded(cm2) ['100-1000']
# Ailanthus altissima Plant height (unspecified if vegetative or reproductive)(cm) ['2600']
# Ailanthus altissima Pollen: 2. diameter (um)(microm) [25.0]
# Ailanthus altissima Seed dry mass(mg) ['33.3']
# Aira caryophyllea Altitude (maximum recorded)(m) ['563']
# Aira caryophyllea Altitude (minimum recorded)(m) ['0', '0', '0', '0', '0']
# Aira caryophyllea Chromosome cDNA content(pg) [12.1]
# Aira caryophyllea First historical record: 1. date(year) [1605]
# Aira caryophyllea Leaf area: in case of compound leaves undefined if leaf or leaflet; undefined if petiole and rhachis in- or excluded(cm2) ['<0.1']
# Aira caryophyllea Maximum temperature of germination(C) [15.0]
# Aira caryophyllea Number of European countries in which native(countries) [26]
# Aira caryophyllea Onset of flowering (first flowering date, beginning of flowering period)(month) ['5', '5', '5']
# Aira caryophyllea Plant height (unspecified if vegetative or reproductive)(cm) ['50', '10']
# Aira caryophyllea Seed dry mass(mg) ['0.17']
# Aira caryophyllea Seed length (largest dimension length)(mm) ['1.0']
# Aira caryophyllea Stem longevity(yrs) ['<1']
# Aira praecox Altitude (maximum recorded)(m) ['685']
# Aira praecox Altitude (minimum recorded)(m) ['0', '0', '0', '0', '0']
# Aira praecox Chromosome cDNA content(pg) [5.9]
# Aira praecox Dispersal unit (dispersule / diaspore) length(mm) ['2.6']
# Aira praecox End of flowering(month) [5]
# Aira praecox First historical record: 1. date(year) [1670]
# Aira praecox Leaf area: in case of compound leaves undefined if leaf or leaflet; undefined if petiole and rhachis in- or excluded(cm2) ['0.1-1']
# Aira praecox Maximum temperature at which 50% seeds germinate(C) [31]
# Aira praecox Maximum temperature of germination(C) [15.0]
# Aira praecox Minimum temperature at which 50% seeds germinate(C) [10]
# Aira praecox Number of European countries in which native(countries) [19]
# Aira praecox Onset of flowering (first flowering date, beginning of flowering period)(month) ['4', '4']
# Aira praecox Plant height (unspecified if vegetative or reproductive)(cm) ['20', '12', '2', '2', '2', '2']
# Aira praecox Plant relative growth rate (RGR)(1/day) ['0.124']
# Aira praecox Root rooting depth (cm) ['0-10']
# Aira praecox Seed dry mass(mg) ['0.18']
# Aira praecox Seed length (largest dimension length)(mm) ['1.6']
# Aira praecox Seedbank density(m-2 ?) ['4030', '83', '888.75']
# Aira praecox Seeds per flower(1/flower) ['1-10']
# Aira praecox Stem longevity(yrs) ['<1']
# Ajuga chamaepitys End of flowering(month) [9]
# Ajuga chamaepitys First historical record: 1. date(year) [1551]
# Ajuga chamaepitys Leaf area: in case of compound leaves undefined if leaf or leaflet; undefined if petiole and rhachis in- or excluded(cm2) ['0.1-1']
# Ajuga chamaepitys Number of European countries in which native(countries) [24]
# Ajuga chamaepitys Plant height (unspecified if vegetative or reproductive)(cm) ['5', '5']
# Ajuga chamaepitys Root rooting depth (cm) ['0-10']
# Ajuga chamaepitys Root rooting depth (text) ['shallow']
# Ajuga chamaepitys Seed dry mass(mg) ['1.16']
# Ajuga chamaepitys Seedbank density(m-2 ?) ['173', '51']
# Ajuga chamaepitys Stem longevity(yrs) ['<1']
# Ajuga pyramidalis Altitude (maximum recorded)(m) ['533', '650']
# Ajuga pyramidalis Altitude (minimum recorded)(m) ['0', '0', '0', '0', '0']
# Ajuga pyramidalis End of flowering(month) [7, 7]
# Ajuga pyramidalis First historical record: 1. date(year) [1777]
# Ajuga pyramidalis Number of European countries in which native(countries) [22]
# Ajuga pyramidalis Onset of flowering (first flowering date, beginning of flowering period)(month) ['5', '5', '5']
# Ajuga pyramidalis Plant height (unspecified if vegetative or reproductive)(cm) ['30', '10']
# Ajuga pyramidalis Seedbank density(m-2 ?) ['263', '88', '161']
# Ajuga pyramidalis Stem longevity(yrs) ['<1']
# Ajuga reptans Altitude (maximum recorded)(m) ['762']
# Ajuga reptans Altitude (minimum recorded)(m) ['0', '0', '0']
# Ajuga reptans End of flowering(month) [7, 7]
# Ajuga reptans Fine root diameter(microm) ['200-300']
# Ajuga reptans First historical record: 1. date(year) [1548]
# Ajuga reptans Leaf area: in case of compound leaves undefined if leaf or leaflet; undefined if petiole and rhachis in- or excluded(cm2) ['10-100']
# Ajuga reptans Leaf petiole length(mm) [1.0, 1.0]
# Ajuga reptans Number of European countries in which native(countries) [25]
# Ajuga reptans Onset of flowering (first flowering date, beginning of flowering period)(month) ['5', '5', '5', '5']
# Ajuga reptans Plant height (unspecified if vegetative or reproductive)(cm) ['30', '10']
# Ajuga reptans Seedbank density(m-2 ?) ['1593', '222.7333333333333333333333333333333']
# Ajuga reptans Stem longevity(yrs) ['<1']
# Ajuga reptans Stomata density on lower surface(mm-2) ['147']
# Ajuga reptans Stomata density on upper surface(mm-2) ['17']
# Alchemilla acutiloba End of flowering(month) [9]
# Alchemilla acutiloba Number of European countries in which native(countries) [19]
# Alchemilla acutiloba Onset of flowering (first flowering date, beginning of flowering period)(month) ['6', '6']
# Alchemilla acutiloba Plant height (unspecified if vegetative or reproductive)(cm) ['65']
# Alchemilla acutiloba Stem longevity(yrs) ['<1']
# Alchemilla alpina Altitude (maximum recorded)(m) ['1271']
# Alchemilla alpina Altitude (minimum recorded)(m) ['67']
# Alchemilla alpina End of flowering(month) [8]
# Alchemilla alpina First historical record: 1. date(year) [1677]
# Alchemilla alpina Leaf area: in case of compound leaves undefined if leaf or leaflet; undefined if petiole and rhachis in- or excluded(cm2) ['1-10']
# Alchemilla alpina Number of European countries in which native(countries) [16]
# Alchemilla alpina Onset of flowering (first flowering date, beginning of flowering period)(month) ['6']
# Alchemilla alpina Plant height (unspecified if vegetative or reproductive)(cm) ['20', '10']
# Alchemilla alpina Stem longevity(yrs) ['<1']
# Alchemilla filicaulis Altitude (maximum recorded)(m) ['870', '915']
# Alchemilla filicaulis Altitude (minimum recorded)(m) ['0', '0']
# Alchemilla filicaulis End of flowering(month) [9, 9]
# Alchemilla filicaulis First historical record: 1. date(year) [1949]
# Alchemilla filicaulis Number of European countries in which native(countries) [19, 1]
# Alchemilla filicaulis Onset of flowering (first flowering date, beginning of flowering period)(month) ['6', '6', '6', '6', '6']
# Alchemilla filicaulis Plant height (unspecified if vegetative or reproductive)(cm) ['40', '5', '5']
# Alchemilla filicaulis Stem longevity(yrs) ['<1', '<1']
# Alchemilla glabra Altitude (maximum recorded)(m) ['1215']
# Alchemilla glabra End of flowering(month) [9]
# Alchemilla glabra Number of European countries in which native(countries) [22]
# Alchemilla glabra Onset of flowering (first flowering date, beginning of flowering period)(month) ['6', '6', '6']
# Alchemilla glabra Plant height (unspecified if vegetative or reproductive)(cm) ['60']
# Alchemilla glabra Stem longevity(yrs) ['<1']
# Alchemilla glaucescens End of flowering(month) [9]
# Alchemilla glaucescens Number of European countries in which native(countries) [21]
# Alchemilla glaucescens Onset of flowering (first flowering date, beginning of flowering period)(month) ['6']
# Alchemilla glaucescens Plant height (unspecified if vegetative or reproductive)(cm) ['20']
# Alchemilla glaucescens Stem longevity(yrs) ['<1']
# Alchemilla glomerulans Altitude (maximum recorded)(m) ['915', '970']
# Alchemilla glomerulans Altitude (minimum recorded)(m) ['185']
# Alchemilla glomerulans Altitude (typical minimum)(m) [600.0]
# Alchemilla glomerulans End of flowering(month) [9]
# Alchemilla glomerulans Number of European countries in which native(countries) [10]
# Alchemilla glomerulans Onset of flowering (first flowering date, beginning of flowering period)(month) ['6']
# Alchemilla glomerulans Plant height (unspecified if vegetative or reproductive)(cm) ['40']
# Alchemilla glomerulans Stem longevity(yrs) ['<1']
# Alchemilla monticola End of flowering(month) [9]
# Alchemilla monticola Number of European countries in which native(countries) [20]
# Alchemilla monticola Onset of flowering (first flowering date, beginning of flowering period)(month) ['6', '6']
# Alchemilla monticola Plant height (unspecified if vegetative or reproductive)(cm) ['40']
# Alchemilla monticola Stem longevity(yrs) ['<1']
# Alchemilla subcrenata End of flowering(month) [9]
# Alchemilla subcrenata Number of European countries in which native(countries) [17]
# Alchemilla subcrenata Onset of flowering (first flowering date, beginning of flowering period)(month) ['6', '6']
# Alchemilla subcrenata Plant height (unspecified if vegetative or reproductive)(cm) ['50']
# Alchemilla subcrenata Stem longevity(yrs) ['<1']
# Alchemilla wichurae Altitude (maximum recorded)(m) ['915', '990']
# Alchemilla wichurae Altitude (minimum recorded)(m) ['0', '0']
# Alchemilla wichurae End of flowering(month) [9]
# Alchemilla wichurae Number of European countries in which native(countries) [8]
# Alchemilla wichurae Onset of flowering (first flowering date, beginning of flowering period)(month) ['6']
# Alchemilla wichurae Plant height (unspecified if vegetative or reproductive)(cm) ['20']
# Alchemilla wichurae Stem longevity(yrs) ['<1']
# Alchemilla xanthochlora End of flowering(month) [9]
# Alchemilla xanthochlora Number of European countries in which native(countries) [21]
# Alchemilla xanthochlora Onset of flowering (first flowering date, beginning of flowering period)(month) ['6', '6', '6']
# Alchemilla xanthochlora Stem longevity(yrs) ['<1']
# Alisma gramineum End of flowering(month) [8]
# Alisma gramineum First historical record: 1. date(year) [1920]
# Alisma gramineum Number of European countries in which native(countries) [18]
# Alisma gramineum Onset of flowering (first flowering date, beginning of flowering period)(month) ['6']
# Alisma gramineum Plant height (unspecified if vegetative or reproductive)(cm) ['60', '5', '30', '15']
# Alisma gramineum Pollen: 2. diameter (um)(microm) [28.0]
# Alisma lanceolatum End of flowering(month) [8, 8]
# Alisma lanceolatum Number of European countries in which native(countries) [30]
# Alisma lanceolatum Onset of flowering (first flowering date, beginning of flowering period)(month) ['6']
# Alisma lanceolatum Plant height (unspecified if vegetative or reproductive)(cm) ['100']
# Alliaria petiolata Altitude (maximum recorded)(m) ['350']
# Alliaria petiolata Altitude (minimum recorded)(m) ['0', '0']
# Alliaria petiolata First historical record: 1. date(year) [1538]
# Orchis anthropophora End of flowering(month) [7, 7]
# Orchis anthropophora First historical record: 1. date(year) [1690]
# Orchis anthropophora Flowering periode: peak month(month) [6]
# Orchis anthropophora Leaf area: in case of compound leaves undefined if leaf or leaflet; undefined if petiole and rhachis in- or excluded(cm2) ['1-10']
# Orchis anthropophora Leaf lamina thickness(mm) ['0.5-1.0']
# Orchis anthropophora Leaf lifespan (longevity, retention time, LL)(month) ['2-6', '6-12', '6-12']
# Orchis anthropophora Leaf petiole length(mm) [0.0, 0.0, 0.0]
# Orchis anthropophora Number of European countries in which native(countries) [16]
# Orchis anthropophora Onset of flowering (first flowering date, beginning of flowering period)(month) ['5', '5']
# Orchis anthropophora Plant height (unspecified if vegetative or reproductive)(cm) ['60', '40', '20']
# Orchis anthropophora Root persistence (livespan, longevity)(years) ['<1', '<1']
# Orchis anthropophora Root rooting depth (cm) ['0-10']
# Orchis anthropophora Root rooting depth (text) ['shallow']
# Orchis anthropophora Seed number per plant(1/plant) ['1000-10000', '>10000']
# Orchis anthropophora Seeds per flower(1/flower) ['100-1000']
